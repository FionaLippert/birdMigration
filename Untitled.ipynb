# %%
import os
import numpy as np
import wradlib as wrl
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sb
import cv2

# %%
fpath = 'birdMigration/testdata/20161001T0000-20161001T0500/NL/DBL/NLDBL_20161001T0000.h5'
fpath = 'birdMigration/testdata/composite_20161001T0000.h5'
f = wrl.util.get_wradlib_data_file(fpath)
fcontent = wrl.io.read_opera_hdf5(f)

# %%
arr = fcontent['VID_data/data']
arr2 = arr.copy()
arr2[arr2 > 50] = np.nan
arr2[arr2 == 0] = np.nan
# Out:
# <ipython-input-29-1ce551ecd015>:3: RuntimeWarning: invalid value encountered in greater
#   arr2[arr2 > 50] = np.nan
# <ipython-input-29-1ce551ecd015>:4: RuntimeWarning: invalid value encountered in equal
#   arr2[arr2 == 0] = np.nan

# %%
plt.imshow(arr[100:1100, 200:])

# %%
print(arr.shape)
sb.distplot(arr2.flatten())
# Out:
# (1205, 1211)

# %%
np.nanmean(arr2[arr2<50])
# Out:
# <ipython-input-28-0692cf17f992>:1: RuntimeWarning: invalid value encountered in less
#   np.nanmean(arr2[arr2<50])
# 1.1490334480301834

# %%
# Resize to desired image shape
img = arr[100:1100, 200:]
img = cv2.resize(img, (128, 128))
img = np.nan_to_num(img)

#img = img.astype(np.float32)
#img = img/np.nanmax(img)

# %%
plt.imshow(np.log(img), cmap='rainbow')
# Out:
# <ipython-input-54-6895f932e540>:1: RuntimeWarning: divide by zero encountered in log
#   plt.imshow(np.log(img), cmap='rainbow')

# %%
from sklearn.model_selection import train_test_split
idx_list = range(0, 50, 3)
idx_train, idx_test = train_test_split(idx_list, test_size=0.2)

# %%
idx_train
# Out:
# [48, 33, 24, 15, 12, 0, 45, 30, 36, 3, 18, 21, 27]

# %%
idx_test
# Out:
# [39, 42, 6, 9]
