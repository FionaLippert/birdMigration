# %%
import numpy as np
import os.path as osp
from matplotlib import pyplot as plt

# %%
base_dir = '/home/fiona/birdMigration/results'

# %%
year = 2015
model = 'FluxGraphLSTM' # LocalLSTM
model_dir = osp.join(base_dir, f'nested_cv_{model}', f'test_{year}', 
                      'LR_estimation', 'trial_1')
lr = np.load(osp.join(model_dir, 'learning_rates.npy'))
loss = np.load(osp.join(model_dir, 'validation_curves.npy')).flatten()

# %%
fig, ax = plt.subplots()
ax.plot(lr[6:-20], loss[6:-20])
ax.set(xscale='log', yscale='log')
lr[6], lr[-20]
# Out:
# (2.985983999999999e-06, 0.009100438150002128)

# %%
fig, ax = plt.subplots()
ax.plot(lr[:55], loss[:55])
ax.set(xscale='log', yscale='log')
# Out:
# [None, None]
